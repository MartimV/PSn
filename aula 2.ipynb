# %%
import pandas as pd

path="excelfiles/"

df=pd.read_excel(path+"O seu município em números! Abrantes.xls")

# %%
df=df[6:78]
df
# Out:
#                                            Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 6                                                 NaN       2010        NaN
# 7                                                 NaN  Abrantes   Portugal
# 8                                População residente       39637   10573100
# 9                                  Superfície em km2           0          0
# 10                            Densidade populacional           0          0
# ..                                                ...        ...        ...
# 73  Crimes registados pelas polícias por mil habit...       32.4       40.1
# 74  Consumo de energia eléctrica por habitante (kWh)      4075.9     4776.8
# 75  Resíduos urbanos recolhidos selectivamente por...       66.2       76.2
# 76             Despesas do município em ambiente (%)           5          8
# 77                         Alojamentos turísticos (6)          4       2011
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# ...
